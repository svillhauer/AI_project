# %%
run main.py
# Out:
# Done! 540 images copied to /home/svillhauer/Desktop/AI Project/UCAMGEN-main/SAMPLE_RANDOM/IMAGES/AUTIMGTR/ and 59 images copied to /home/svillhauer/Desktop/AI Project/UCAMGEN-main/SAMPLE_RANDOM/IMAGES/AUTIMGTS/.
# PROCESSING MODEL /home/svillhauer/Desktop/AI Project/AUTOENCODER-main/MODELSTEST3/AUTOENCODER_128_128_32_EPOCHS100
# TRAINING THE MODEL
# Epoch 1/100
# /home/svillhauer/anaconda3/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /home/svillhauer/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ...

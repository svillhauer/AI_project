# %%
run loopmodeltest.py
# Out:
# 2024-12-17 07:11:22.168947: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-12-17 07:11:22.168968: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:135] retrieving CUDA diagnostic information for host: svillhauer-Precision-5690
# 2024-12-17 07:11:22.168971: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:142] hostname: svillhauer-Precision-5690
# 2024-12-17 07:11:22.169071: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:166] libcuda reported version is: 550.120.0
# 2024-12-17 07:11:22.169080: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] kernel reported version is: 550.120.0
# 2024-12-17 07:11:22.169082: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:249] kernel version seems to match DSO: 550.120.0
# ...
